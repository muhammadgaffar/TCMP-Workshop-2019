# %%
using PyPlot

# %%
func(x) = sin(x)*tanh(x) - 0.01x^3
# Out:
# func (generic function with 1 method)

# %%
x = range(-5,length=15,stop=5)
x = collect(x);

# %%
y = func.(x);

# %%
plot(x,y,"-o")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7feb20ff7710>

# %%
using DelimitedFiles
